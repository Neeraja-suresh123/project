# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
from google.colab import files
files.upload()
# Out:
#      <input type="file" id="files-8d817987-5938-4d3a-9d3e-da1d6cc6a874" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8d817987-5938-4d3a-9d3e-da1d6cc6a874">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data=pd.read_csv("/content/healthcare-dataset-stroke-data.csv")

# %% [markdown]
# **EDA**

# %%
data.head()
# Out:
#       id  gender   age  hypertension  heart_disease ever_married  \
# 0   9046    Male  67.0             0              1          Yes
# 1  51676  Female  61.0             0              0          Yes
# 2  31112    Male  80.0             0              1          Yes
# 3  60182  Female  49.0             0              0          Yes
# 4   1665  Female  79.0             1              0          Yes
#
#        work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0        Private          Urban             228.69  36.6  formerly smoked
# 1  Self-employed          Rural             202.21   NaN     never smoked
# 2        Private          Rural             105.92  32.5     never smoked
# 3        Private          Urban             171.23  34.4           smokes
# 4  Self-employed          Rural             174.12  24.0     never smoked
#
#    stroke
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
data.shape
# Out:
# (5110, 12)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 12 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   id                 5110 non-null   int64
#  1   gender             5110 non-null   object
#  2   age                5110 non-null   float64
#  3   hypertension       5110 non-null   int64
#  4   heart_disease      5110 non-null   int64
#  5   ever_married       5110 non-null   object
#  6   work_type          5110 non-null   object
#  7   Residence_type     5110 non-null   object
#  8   avg_glucose_level  5110 non-null   float64
#  9   bmi                4909 non-null   float64
#  10  smoking_status     5110 non-null   object
#  11  stroke             5110 non-null   int64
# dtypes: float64(3), int64(4), object(5)
# memory usage: 479.2+ KB

# %%
data.dtypes
# Out:
# id                     int64
# gender                object
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married          object
# work_type             object
# Residence_type        object
# avg_glucose_level    float64
# bmi                  float64
# smoking_status        object
# stroke                 int64
# dtype: object

# %%
data.describe()
# Out:
#                  id          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354    43.226614      0.097456       0.054012
# std    21161.721625    22.612647      0.296607       0.226063
# min       67.000000     0.080000      0.000000       0.000000
# 25%    17741.250000    25.000000      0.000000       0.000000
# 50%    36932.000000    45.000000      0.000000       0.000000
# 75%    54682.000000    61.000000      0.000000       0.000000
# max    72940.000000    82.000000      1.000000       1.000000
#
#        avg_glucose_level          bmi       stroke
# count        5110.000000  4909.000000  5110.000000
# mean          106.147677    28.893237     0.048728
# std            45.283560     7.854067     0.215320
# min            55.120000    10.300000     0.000000
# 25%            77.245000    23.500000     0.000000
# 50%            91.885000    28.100000     0.000000
# ...

# %%
data.tail()
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0

# %%
data['gender'].unique()
# Out:
# array(['Male', 'Female', 'Other'], dtype=object)

# %%
data['ever_married'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
data['work_type'].unique()
# Out:
# array(['Private', 'Self-employed', 'Govt_job', 'children', 'Never_worked'],
#       dtype=object)

# %%
data['Residence_type'].unique()
# Out:
# array(['Urban', 'Rural'], dtype=object)

# %%
data['smoking_status'].unique()
# Out:
# array(['formerly smoked', 'never smoked', 'smokes', 'Unknown'],
#       dtype=object)

# %%
data['gender'].value_counts()
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64

# %% [markdown]
# **Plots**

# %%
## correlation
corrmatrix=data.corr()
plt.subplots(figsize=(10,4))
sns.heatmap(corrmatrix,annot=True,vmin=-0.2,vmax=1,cmap='YlGnBu')
# Out:
# <ipython-input-16-3592002b61d6>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corrmatrix=data.corr()
# <Axes: >

# %%
sns.pairplot(data)

# %%
slice_data = data[['age','hypertension','heart_disease','stroke']]

# %%
sns.pairplot(slice_data)

# %%
freqgraph=data.select_dtypes(include=['float'])
freqgraph.hist(figsize=(20,15))
plt.show()

# %% [markdown]
# **Heat map**

# %%
plt.figure(figsize=(17,18))
corr=data.corr()
sns.heatmap(corr,annot=True,cmap=plt.cm.Blues,fmt='.2f')
# Out:
# <ipython-input-21-92ad53cdbc72>:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr=data.corr()
# <Axes: >

# %% [markdown]
# **Age**

# %%
plt.boxplot(data['age'])
plt.title('stroke vs age')###Age doesn't include any outliers.
# Out:
# Text(0.5, 1.0, 'stroke vs age')

# %%
###How does age relate to stroke?
plt.hist(data['age'],edgecolor='black')
plt.xlabel('age')
plt.ylabel('count')
plt.title('Stroke vs age')
plt.show() ###People with age > 40 tend to have stroke more than younger people.

# %%
sns.kdeplot(x=data['age'])
plt.title('Stroke vs Age')
plt.legend(['Stroke'])

# %% [markdown]
# **Gender**

# %%
sns.countplot(x=data['gender'])
plt.title('Stroke Vs gender') ###Most people in the dataset are female
# Out:
# Text(0.5, 1.0, 'Stroke Vs gender')

# %%
plt.hist(data['gender'],edgecolor='black')
plt.xlabel('gender')
plt.ylabel('count')
plt.title('Stroke vs Gender')
plt.show()

# %%
data['gender'].value_counts().plot(kind='pie',figsize=(6,6),shadow=True,autopct='%1.1f%%')
plt.title('Pie chart of Gender ')
plt.legend()

# %% [markdown]
# Hypertension

# %%
data['hypertension'].value_counts().plot(kind='pie',figsize=(6,6),shadow=True,autopct='%1.1f%%')
plt.title('Pie chart of Hypertension ')
plt.legend()

# %%
fig, ax = plt.subplots(figsize=(9, 5))
plt.title(' Stroke vs Hypertension ')###Most people don't have hypertension.

sns.countplot(x=data['hypertension'])
ax.set_xticklabels(['No hypertension disease', 'hypertension disease'])
# Out:
# [Text(0, 0, 'No hypertension disease'), Text(1, 0, 'hypertension disease')]

# %%
plt.hist(data['hypertension'],edgecolor='black')
plt.xlabel('hypertension')
plt.ylabel('count')
plt.title('Stroke vs Hypertension')
plt.show()

# %% [markdown]
# **Heart Disease**

# %%
fig, ax = plt.subplots(figsize=(9, 5))
plt.title('Heart Disease Distribution')
sns.countplot(x=data['heart_disease'])
ax.set_xticklabels(['No heart disease', 'Heart disease'])
# Out:
# [Text(0, 0, 'No heart disease'), Text(1, 0, 'Heart disease')]

# %%
data['heart_disease'].value_counts().plot(kind='pie',figsize=(6,6),shadow=True,autopct='%1.1f%%')
plt.title('Pie chart of Heart Disease')
plt.legend()

# %%
plt.hist(data['heart_disease'],edgecolor='black')
plt.xlabel('heart_disease')
plt.ylabel('count')
plt.title('Stroke vs Heart Disease')
plt.show()

# %% [markdown]
# **Ever Married**

# %%
plt.hist(data['ever_married'],edgecolor='black')
plt.xlabel('ever_married')
plt.ylabel('count')
plt.title('Stroke vs Ever Married')
plt.show()

# %%
sns.countplot(x=data['ever_married']) ###Most people in the dataset have married before.
plt.title('Stroke vs ever_married')
# Out:
# Text(0.5, 1.0, 'Stroke vs ever_married')

# %%
data['ever_married'].value_counts().plot(kind='pie',figsize=(6,6),shadow=True,autopct='%1.1f%%')
plt.title('Pie chart of Ever Married')
plt.legend()

# %% [markdown]
# **Work Type**

# %%
sns.countplot(x=data['work_type']) ###Most people have a work type of private.
plt.title('Stroke vs work_type')
# Out:
# Text(0.5, 1.0, 'Stroke vs work_type')

# %%
plt.hist(data['work_type'],edgecolor='black')
plt.xlabel('work_type')
plt.ylabel('count')
plt.title('Stroke vs Work Type')
plt.show()

# %%
data['work_type'].value_counts().plot(kind='pie',figsize=(6,6),shadow=True,autopct='%1.1f%%')
plt.title('Pie chart of Work type')
plt.legend()

# %% [markdown]
# **Residence type**

# %%
sns.countplot(x=data['Residence_type'])
plt.title('Stroke vs Residence type')
# Out:
# Text(0.5, 1.0, 'Stroke vs Residence type')

# %%
data['Residence_type'].value_counts().plot(kind='pie',figsize=(6,6),shadow=True,autopct='%1.1f%%')
plt.title('Pie chart of Residence type')
plt.legend()

# %% [markdown]
# Avg_glucose_level

# %%
sns.countplot(x=data['avg_glucose_level'])
plt.title('Stroke vs Avg_glucose_level')
# Out:
# Text(0.5, 1.0, 'Stroke vs Avg_glucose_level')

# %%
sns.kdeplot(x=data['avg_glucose_level'])
plt.title('Stroke vs Avg_glucose_level')####People with an average glucose level > 100 are more likely to have stroke.
plt.legend(['Stroke'])

# %%
plt.boxplot(data['avg_glucose_level'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f1fa6e6ad40>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f1fa6e69060>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f1fa6e69e70>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1fa7066f20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1fa7066140>],
#  'means': []}

# %%
plt.hist(data['avg_glucose_level'],edgecolor='black')
plt.xlabel('avg_glucose_level')
plt.ylabel('count')
plt.title('Stroke vs Avg_glucose_level')
plt.show()

# %% [markdown]
# **BMI**

# %%
sns.kdeplot(x=data['bmi'])
plt.title('Stroke vs BMI')
plt.legend(['Stroke'])
##doubt

# %%
sns.boxplot(x=data['bmi'])
# Out:
# <Axes: xlabel='bmi'>

# %% [markdown]
# Smoking Status

# %%
sns.countplot(x=data['smoking_status'])
plt.title('Stroke vs smoking_status')####Most people never smoked.
# Out:
# Text(0.5, 1.0, 'Stroke vs smoking_status')

# %%
plt.hist(data['smoking_status'],edgecolor='black')
plt.xlabel('smoking_status')
plt.ylabel('count')
plt.title('Stroke vs Smoking Status')
plt.show()

# %%
data['smoking_status'].value_counts().plot(kind='pie',figsize=(6,6),shadow=True,autopct='%1.1f%%')
plt.title('Pie chart of Smoking status')
plt.legend()

# %% [markdown]
# **Target Analysis**

# %%
data['stroke'].value_counts().plot.bar(color='Red')
# Out:
# <Axes: >

# %%
data['stroke'].value_counts().plot(kind='pie',figsize=(6,6),shadow=True,autopct='%1.1f%%')
# Out:
# <Axes: ylabel='stroke'>

# %% [markdown]
# **Preprocessing**

# %% [markdown]
#  Handling missing values

# %%
data.isna().sum()
# Out:
# id                     0
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
data['bmi']=data['bmi'].fillna(data['bmi'].mean)

# %%
data.isna().sum()
# Out:
# id                   0
# gender               0
# age                  0
# hypertension         0
# heart_disease        0
# ever_married         0
# work_type            0
# Residence_type       0
# avg_glucose_level    0
# bmi                  0
# smoking_status       0
# stroke               0
# dtype: int64

# %% [markdown]
#  Encoding categorical variables

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder=LabelEncoder()
for col in data.columns:
  if data[col].dtype=='object':
    data[col]=label_encoder.fit_transform(data[col].astype(str))

# %%
data.dtypes
# Out:
# id                     int64
# gender                 int64
# age                  float64
# hypertension           int64
# heart_disease          int64
# ever_married           int64
# work_type              int64
# Residence_type         int64
# avg_glucose_level    float64
# bmi                    int64
# smoking_status         int64
# stroke                 int64
# dtype: object

# %%
data.head()
# Out:
#       id  gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0   9046       1  67.0             0              1             1          2
# 1  51676       0  61.0             0              0             1          3
# 2  31112       1  80.0             0              1             1          2
# 3  60182       0  49.0             0              0             1          2
# 4   1665       0  79.0             1              0             1          3
#
#    Residence_type  avg_glucose_level  bmi  smoking_status  stroke
# 0               1             228.69  239               1       1
# 1               0             202.21  418               2       1
# 2               0             105.92  198               2       1
# 3               1             171.23  217               3       1
# 4               0             174.12  113               2       1

# %%
data.describe()
# Out:
#                  id       gender          age  hypertension  heart_disease  \
# count   5110.000000  5110.000000  5110.000000   5110.000000    5110.000000
# mean   36517.829354     0.414286    43.226614      0.097456       0.054012
# std    21161.721625     0.493044    22.612647      0.296607       0.226063
# min       67.000000     0.000000     0.080000      0.000000       0.000000
# 25%    17741.250000     0.000000    25.000000      0.000000       0.000000
# 50%    36932.000000     0.000000    45.000000      0.000000       0.000000
# 75%    54682.000000     1.000000    61.000000      0.000000       0.000000
# max    72940.000000     2.000000    82.000000      1.000000       1.000000
#
#        ever_married    work_type  Residence_type  avg_glucose_level  \
# count   5110.000000  5110.000000     5110.000000        5110.000000
# mean       0.656164     2.167710        0.508023         106.147677
# std        0.475034     1.090293        0.499985          45.283560
# ...

# %%
plt.boxplot(data['age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f1f9e19a200>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f1f9e19a740>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f1f9e199f60>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1f9e19ac80>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1f9e19af20>],
#  'means': []}

# %%
plt.boxplot(data['gender'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f1f9dfa0430>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f1f9dfa0850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f1f9dfa0190>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1f9dfa0d90>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1f9dfa1030>],
#  'means': []}

# %%
plt.boxplot(data['avg_glucose_level'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f1f9e00c9a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f1f9e00cee0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f1f9e00c7f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1f9e00d420>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1f9e00d6c0>],
#  'means': []}

# %%
plt.boxplot(data['bmi'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f1f9de56c20>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f1f9de57040>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f1f9de56980>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f1f9de57580>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f1f9de57820>],
#  'means': []}

# %%
#capping
def iqr_capping(df,variables):
  
  q1=df[variables].quantile(0.25)
  q3=df[variables].quantile(0.75)
  iqr=q3-q1
  upper_whisker=q3+(1.5*iqr)
  lower_whisker=q1-(1.5*iqr)
  return lower_whisker,upper_whisker

# %%
lower_avg_glucose_level,upper_avg_glucose_level=iqr_capping(data,'avg_glucose_level')
print('lower avg_glucose_level = ',lower_avg_glucose_level)
print('upper avg_glucose_level = ',upper_avg_glucose_level)
data['avg_glucose_level']=np.where(data['avg_glucose_level']>upper_avg_glucose_level,upper_avg_glucose_level,
                    np.where(data['avg_glucose_level']<lower_avg_glucose_level,lower_avg_glucose_level,data['avg_glucose_level']))
# Out:
# lower avg_glucose_level =  21.977500000000006
# upper avg_glucose_level =  169.35750000000002

# %%
lower_bmi,upper_bmi=iqr_capping(data,'bmi')
print('lower bmi = ',lower_bmi)
print('upper bmi = ',upper_bmi)
data['bmi']=np.where(data['bmi']>upper_bmi,upper_bmi,
                    np.where(data['bmi']<lower_bmi,lower_bmi,data['bmi']))
# Out:
# lower bmi =  -42.0
# upper bmi =  366.0

# %%
for i in ['avg_glucose_level','bmi']:
  plt.figure()
  plt.boxplot(data[i])
  plt.title(i)

# %%
data.drop(['id'],axis=1,inplace=True)
data.head()
# Out:
#    gender   age  hypertension  heart_disease  ever_married  work_type  \
# 0       1  67.0             0              1             1          2
# 1       0  61.0             0              0             1          3
# 2       1  80.0             0              1             1          2
# 3       0  49.0             0              0             1          2
# 4       0  79.0             1              0             1          3
#
#    Residence_type  avg_glucose_level    bmi  smoking_status  stroke
# 0               1           169.3575  239.0               1       1
# 1               0           169.3575  366.0               2       1
# 2               0           105.9200  198.0               2       1
# 3               1           169.3575  217.0               3       1
# 4               0           169.3575  113.0               2       1

# %%
x =data.drop(['stroke'],axis=1)
y =data['stroke']

# %% [markdown]
# Over-Sample using SMOTE

# %%
from imblearn.over_sampling import SMOTE
sm = SMOTE(random_state=42)
x_sm , y_sm = sm.fit_resample(x,y)

print(f'''Shape of x before SMOTE:{x.shape}
Shape of x after SMOTE:{x_sm.shape}''',"\n\n")

print(f'''Target Class distributuion before SMOTE:\n{y.value_counts(normalize=True)}
Target Class distributuion after SMOTE :\n{y_sm.value_counts(normalize=True)}''')
# Out:
# Shape of x before SMOTE:(5110, 10)
# Shape of x after SMOTE:(9722, 10)
#
#
# Target Class distributuion before SMOTE:
# 0    0.951272
# 1    0.048728
# Name: stroke, dtype: float64
# Target Class distributuion after SMOTE :
# 1    0.5
# 0    0.5
# Name: stroke, dtype: float64

# %% [markdown]
# Split Test and Train Datasets

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_sm,y_sm,test_size = .2,random_state = 42)
x_train.shape, y_train.shape, x_test.shape, y_test.shape
# Out:
# ((7777, 10), (7777,), (1945, 10), (1945,))

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x_train)
x_train = scaler.transform(x_train)
x_test = scaler.transform(x_test)

# %% [markdown]
# **Modeling**

# %% [markdown]
# **Logistic Regression**

# %%
from sklearn.linear_model import LogisticRegression
logit_model=LogisticRegression()
logit_model.fit(x_train,y_train)
y_pred=logit_model.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score
print('Accuracy is',accuracy_score(y_test,y_pred))
print('precision is',precision_score(y_test,y_pred,average='macro'))
print('Recall is',recall_score(y_test,y_pred,average='macro'))
print('f1 score is',f1_score(y_test,y_pred,average='macro'))
# Out:
# Accuracy is 0.8128534704370179
# precision is 0.813538285176678
# Recall is 0.8129130319851969
# f1 score is 0.8127702742728511

# %% [markdown]
#  KNN

# %%
from sklearn.neighbors import KNeighborsClassifier
metric_k=[]
neighbors=np.arange(3,15)

for k in neighbors:
  classifier =KNeighborsClassifier(n_neighbors=k,metric='minkowski',p=2)
  classifier.fit(x_train,y_train)
  y_pred=classifier.predict(x_test)
  acc=accuracy_score(y_test,y_pred)
  metric_k.append(acc)

# %%
plt.plot(neighbors,metric_k,'o-')
plt.xlabel('k value')
plt.ylabel('accuracy')
plt.grid()

# %%
classifier=KNeighborsClassifier(n_neighbors=4,metric='minkowski',p=2)
classifier.fit(x_train,y_train)
y_pred=classifier.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score
print('Accuracy is',accuracy_score(y_test,y_pred))
print('precision is',precision_score(y_test,y_pred,average='macro'))
print('Recall is',recall_score(y_test,y_pred,average='macro'))
print('f1 score is',f1_score(y_test,y_pred,average='macro'))
# Out:
# Accuracy is 0.900771208226221
# precision is 0.9029821872349291
# Recall is 0.9008670367433254
# f1 score is 0.9006497722184595

# %% [markdown]
# SVM model

# %%
###SVM model
from sklearn.svm import SVC
svmclf=SVC(kernel='linear')
svmclf.fit(x_train,y_train)
y_pred = svmclf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score,confusion_matrix
print('Accuracy is:',accuracy_score(y_test,y_pred))
print('precision is',precision_score(y_test,y_pred,average='macro'))
print('Recall is',recall_score(y_test,y_pred,average='macro'))
print('f1 score is',f1_score(y_test,y_pred,average='macro'))
# Out:
# Accuracy is: 0.8123393316195373
# precision is 0.8132507638840296
# Recall is 0.8124081416864922
# f1 score is 0.8122249697875088

# %%
###SVM model
from sklearn.svm import SVC
svmclf=SVC(kernel='rbf')
svmclf.fit(x_train,y_train)
y_pred = svmclf.predict(x_test)

# %%
from sklearn.metrics import confusion_matrix,accuracy_score,precision_score,recall_score,f1_score
print('Accuracy is',accuracy_score(y_test,y_pred))
print('precision is',precision_score(y_test,y_pred,average='macro'))
print('Recall is',recall_score(y_test,y_pred,average='macro'))
print('f1 score is',f1_score(y_test,y_pred,average='macro'))
# Out:
# Accuracy is 0.8611825192802056
# precision is 0.8634730271388087
# Recall is 0.8612846946867565
# f1 score is 0.860986696653198

# %% [markdown]
# **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
dt_clf = DecisionTreeClassifier(random_state=42)
dt_clf.fit(x_train,y_train)
y_pred = dt_clf.predict(x_test)

# %%
print('Accuracy is', accuracy_score(y_test,y_pred))
print('Precision is', precision_score(y_test,y_pred))
print('Recall is', recall_score(y_test,y_pred))
print('f1 score is', f1_score(y_test,y_pred))
confusion_matrix(y_test,y_pred)
# Out:
# Accuracy is 0.913624678663239
# Precision is 0.903420523138833
# Recall is 0.9257731958762887
# f1 score is 0.914460285132383
# array([[879,  96],
#        [ 72, 898]])

# %% [markdown]
# **Random Forest**

# %%
## random forest algorithm ensemble method
from sklearn.ensemble import RandomForestClassifier
rf_clf = RandomForestClassifier()
rf_clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred= rf_clf.predict(x_test)
y_pred
print('Accuracy is: ',accuracy_score(y_test,y_pred))
print('Precision is', precision_score(y_test,y_pred))
print('Recall is', recall_score(y_test,y_pred))
print('f1 score is', f1_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# Accuracy is:  0.9485861182519281
# Precision is 0.9367469879518072
# Recall is 0.9618556701030928
# f1 score is 0.9491353001017294
# [[912  63]
#  [ 37 933]]

# %% [markdown]
# Hyper parameter tuning

# %%
#hyper parameter tuning
rf_clf = RandomForestClassifier(n_estimators=20,max_depth=3,criterion='entropy',min_samples_split=2)
rf_clf.fit(x_train,y_train)
# Out:
# RandomForestClassifier(criterion='entropy', max_depth=3, n_estimators=20)

# %%
y_pred= rf_clf.predict(x_test)
y_pred
# Out:
# array([0, 1, 1, ..., 1, 0, 1])

# %%
print('Accuracy is: ',accuracy_score(y_test,y_pred))
print('Precision is', precision_score(y_test,y_pred))
print('Recall is', recall_score(y_test,y_pred))
print('f1 score is', f1_score(y_test,y_pred))
print(confusion_matrix(y_test,y_pred))
# Out:
# Accuracy is:  0.7948586118251928
# Precision is 0.7274900398406374
# Recall is 0.9412371134020618
# f1 score is 0.8206741573033708
# [[633 342]
#  [ 57 913]]
